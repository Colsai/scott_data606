# %% [markdown]
# <a href="https://colab.research.google.com/github/Colsai/scott_data606/blob/main/data_preparation_eda/OIGworkplan_Initial_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OIG Workplan & Reports EDA (Step 1)
# An Exploratory Analysis of Current HHS OIG Workplan and Reports data.
# Notes on the scraping and methodology can be found in the project folder.
#
# ## Objectives:
# - Explore and Visualize the Initial Data for the *Workplan_df* and its connected *Reports_df*
# - Create Word Clouds Based on some initial text cleaning

# %% [markdown]
# ## EDA: Work Plan Data
# - The OIG workplan is a tabular re-creation of all of the current (and former) ongoing HHS OIG work from FY2018 on. It includes both the work plans, and connected reports, defined as:
#
# **OIG Work Plans**: Work Plans are general overviews of the scope of the project that OIG is looking to undertake.
# **OIG Reports**: Summaries of the work undertaken, as well as the findings and recommendations for that work product.
#
# *Note:* OIG's work plans are connected to a report, however, there is ongoing work, so not every work plan will have an attached report. However, some work plans may have more than one connected report.

# %%
#For Cleaner Notebook Display
from IPython.display import clear_output

# %%
#Import Packages
import pandas as pd
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from nltk.tokenize import RegexpTokenizer
from nltk.stem import RegexpStemmer
from wordcloud import WordCloud, STOPWORDS

nltk.download(['punkt', 
               'stopwords'])

warnings.filterwarnings('ignore')
clear_output()

# %% [markdown]
# ## a. Load DataFrames from Scraped Sources
# - Workplan_df: The OIG Work Plan, a list and summaries of work that OIG is (or has) undertaken.
# - Reports_df: All scraped, connected reports to any listed work plan items.

# %%
###########################
# Load CSVs (Github)      #
###########################
workplan_df = pd.read_csv("https://github.com/Colsai/scott_data606/blob/main/Data_Sources/HHS_workplan_summaries.csv?raw=true")

#Drop typo column
workplan_df.drop(columns = 'Office of Evaluation and Inspections', 
                 inplace = True)

reports_df = pd.read_csv("https://github.com/Colsai/scott_data606/blob/main/Data_Sources/HHS_OIG_Reports.csv?raw=true")

#Drop dead column
reports_df.drop(columns = 'Unnamed: 0',
                inplace = True)

workplan_df['Agency'] = ["Centers for Medicare and Medicaid Services" if agncy == "Centers for Medicare & Medicaid Services" else agncy for agncy in workplan_df['Agency']]

# %% [markdown]
# ## b. Initial Overview of Data
# Analyze the Workplan Data

# %%
#Print Basic Stats for Both Dataframes:
print(f"{workplan_df.info()}{reports_df.info()}")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 659 entries, 0 to 658
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Announced or Revised      659 non-null    object
#  1   Agency                    659 non-null    object
#  2   Title                     659 non-null    object
#  3   Component                 658 non-null    object
#  4   Report Number(s)          659 non-null    object
#  5   Expected Issue Date (FY)  656 non-null    object
#  6   Website_Link              659 non-null    object
#  7   Summary                   659 non-null    object
# dtypes: object(8)
# memory usage: 41.3+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737 entries, 0 to 736
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Report Number(s)  737 non-null    object
#  1   Workplan_Title    599 non-null    object
#  2   Workplan_Summary  598 non-null    object
# dtypes: object(3)
# memory usage: 17.4+ KB
# NoneNone

# %% [markdown]
# ## Work Plans:

# %%
#What are the statuses of all items?
workplan_df['Announced or Revised'].value_counts()[0:10]
# Out:
# Completed              266
# Revised                115
# Completed (partial)     70
# Nov-16                  29
# Removed                 28
# November 2021           11
# February 2022           10
# June 2021                8
# December 2021            7
# January 2022             6
# Name: Announced or Revised, dtype: int64

# %% [markdown]
# ## Are products listed more than once?

# %%
#Multiple-Listed Audits/Evaluations
workplan_titles = workplan_df.Title.value_counts().reset_index()

workplan_titles.columns = ['Summary_Title', 
                           'Count']

workplan_titles[workplan_titles['Count'] > 1]
# Out:
#                                         Summary_Title  Count
# 0   Ensuring Dual-Eligible Beneficiaries' Access t...      5
# 1   Superfund Financial Activities at the National...      3
# 2   Mandatory Review of HHS Agencies' Annual Accou...      2
# 3   OIG Oversight of State Medicaid Fraud Control ...      2
# 4   Audit of the Department of Health and Human Se...      2
# 5   Comparison of Average Sales Prices and Average...      2
# 6   Audit of Administration for Community Living's...      2
# 7   State Medicaid Fraud Control Units FY 2017 Ann...      2
# 8   HHS Compliance with the Improper Payment Elimi...      2
# 9   Meeting the Challenges Presented by COVID-19: ...      2
# 10  Review of the Food and Drug Administration's C...      2
# 11  Office of Refugee Resettlement Influx Care Fac...      2
# 12  Grantees' Use of President's Emergency Plan fo...      2
# 13  Audit of the Food and Drug Administration's Pr...      2
# 14  Emergency Preparedness and Response at Care Pr...      2
# 15  States' Oversight of Medicaid Managed Care Med...      2
# 16  HHS Agencies' Annual Accounting of Drug-Contro...      2
# 17  NIH Oversight of Foreign Grant Recipients' Com...      2
# 18             Skilled Nursing Facility Reimbursement      2

# %% [markdown]
# Titles can remain the same, since some work products can be repeated year to year. However, let's check the unique identifiers to see if there are true duplicates in the dataset.

# %%
workplan_df["Report Number(s)"].value_counts()
# Out:
# W-00-22-59465                   2
# W-00-22-59467                   2
# W-00-21-59458                   2
# OEI-09-18-00180                 2
# A-04-20-02031;W-00-20-20021     2
#                                ..
# W-00-17-35801, W-00-21-35801    1
# W-00-17-35803; A-05-xx-xxxxx    1
# A-18-17-04002                   1
# OEI-02-17-00490                 1
# OEI-05-22-00330                 1
# Name: Report Number(s), Length: 653, dtype: int64

# %% [markdown]
# It looks like there are a few duplicates. Let's remove these duplicates out, so that there aren't any potential issues.

# %%
workplan_df[workplan_df["Report Number(s)"].notna()]
# Out:
#     Announced or Revised                                      Agency  \
# 0              Completed    Administration for Children and Families
# 1              Completed    Administration for Children and Families
# 2              Completed    Administration for Children and Families
# 3                 Nov-16    Administration for Children and Families
# 4           October 2020    Administration for Children and Families
# ..                   ...                                         ...
# 654            June 2022  Centers for Medicare and Medicaid Services
# 655            June 2022  Centers for Medicare and Medicaid Services
# 656            June 2022    Administration for Children and Families
# 657            June 2022                       Indian Health Service
# 658            June 2022  Centers for Medicare and Medicaid Services
#
#                                                  Title  \
# 0    States' Accuracy of Reporting TANF Spending In...
# 1    Head Start: Review of Single Audit Findings an...
# 2       Unaccompanied Children Program Grantee Reviews
# 3    Recommendation Follow-Up: Office of Refugee Re...
# 4    ACF Oversight of Guardian Ad Litem Requirement...
# ..                                                 ...
# 654  Medicare Administrative Contractor Cost Report...
# 655  States' and MCOs' Compliance With Mental Healt...
# 656  Audit of the Low Income Home Energy Assistance...
# 657  Indian Health Service Capacity To Manage Suppl...
# 658  Strategies To Improve Access to Maternal Healt...
#
#                                 Component  \
# 0                Office of Audit Services
# 1                Office of Audit Services
# 2                Office of Audit Services
# 3    Office of Evaluation and Inspections
# 4    Office of Evaluation and Inspections
# ..                                    ...
# 654              Office of Audit Services
# 655              Office of Audit Services
# 656              Office of Audit Services
# 657  Office of Evaluation and Inspections
# 658  Office of Evaluation and Inspections
#
#                                       Report Number(s)  \
# 0                        A-02-17-02005;  W-00-17-25100
# 1    A-02-16-02009,  A-09-16-01004,  A-06-17-07003;...
# 2    A-02-16-02013;  A-04-16-03566;  A-02-16-02007;...
# 3                                      OEI-09-16-00260
# 4                                      OEI-12-16-00120
# ..                                                 ...
# 654                                      W-00-22-35886
# 655                                      W-00-22-31565
# 656                                      W-00-22-20036
# 657                                    OEI-06-22-00320
# 658                                    OEI-05-22-00330
#
#     Expected Issue Date (FY)  \
# 0                       2021
# 1                       2018
# 2                       2020
# 3                       2017
# 4                       2022
# ..                       ...
# 654                     2023
# 655                     2023
# 656                     2023
# 657                     2023
# 658                     2023
#
#                                           Website_Link  \
# 0    https://oig.hhs.gov/reports-and-publications/w...
# 1    https://oig.hhs.gov/reports-and-publications/w...
# 2    https://oig.hhs.gov/reports-and-publications/w...
# 3    https://oig.hhs.gov/reports-and-publications/w...
# 4    https://oig.hhs.gov/reports-and-publications/w...
# ..                                                 ...
# 654  https://oig.hhs.gov/reports-and-publications/w...
# 655  https://oig.hhs.gov/reports-and-publications/w...
# 656  https://oig.hhs.gov/reports-and-publications/w...
# 657  https://oig.hhs.gov/reports-and-publications/w...
# 658  https://oig.hhs.gov/reports-and-publications/w...
#
#                                                Summary
# 0    The Temporary Assistance for Needy Families (T...
# 1    Effective for awards made on or after December...
# 2    Under the Homeland Security Act of 2002, § 462...
# 3    Under the Homeland Security Act of 2002, § 462...
# 4    As a condition of receiving Child Abuse Preven...
# ..                                                 ...
# 654  HHS contracts with Medicare Administrative Con...
# 655  The Paul Wellstone and Pete Domenici Mental He...
# 656  The Low Income Home Energy Assistance Program ...
# 657  The Indian Health Service (IHS) Sanitation Fac...
# 658  Pregnant people in the United States experienc...
#
# [659 rows x 8 columns]

# %%
#Drop Duplicates for Summaries Data
mask = workplan_df["Report Number(s)"].notna()

workplan_df = workplan_df[mask].drop_duplicates()

workplan_df.shape
# Out:
# (659, 8)

# %% [markdown]
# ### What Agencies are commonly the scope of OIG's reporting?

# %%
#Top-5 Agencies from Work Plans
pd.DataFrame(workplan_df['Agency'].value_counts())[0:10]
# Out:
#                                                     Agency
# Centers for Medicare and Medicaid Services             415
# Administration for Children and Families                46
# National Institutes of Health                           26
# Food and Drug Administration                            20
# Centers for Disease Control and Prevention              18
# Indian Health Service                                   15
# OS                                                      14
# Other                                                   14
# Health Resources and Services Administration            13
# Substance Abuse and Mental Health Services Admi...      13

# %% [markdown]
# ### - What is the scope of the represented from work plan data?
# - Office of Audit Services = Audits
# - Office of Evaluation and Inspections = Evaluations

# %%
#Standardize Data
workplan_df['Component'] = ["Office of Evaluation and Inspections" 
                            if comp == "Office of Evaluation and Inspection" else comp
                            for comp in workplan_df['Component']]

#Show Top-5 Agencies from Work Plans
df_components = pd.DataFrame(workplan_df['Component'].value_counts())
df_components
# Out:
#                                                     Component
# Office of Audit Services                                  423
# Office of Evaluation and Inspections                      234
# Office of Audit Services and Office of Evaluati...          1

# %% [markdown]
# ## OIG Reports

# %%
reports_df.head()
# Out:
#   Report Number(s)                                     Workplan_Title  \
# 0    A-02-17-02005  New York Did Not Have Adequate Oversight of It...
# 1    A-02-16-02009  The Administration for Children and Families R...
# 2    A-09-16-01004  The Administration for Children and Families R...
# 3    A-06-17-07003  The Administration for Children and Families D...
# 4    A-02-16-02013  The Children's Village, Inc., an Administratio...
#
#                                     Workplan_Summary
# 0  The Temporary Assistance for Needy Families (T...
# 1  The Administration for Children and Families (...
# 2  Head Start grantees are required to have Singl...
# 3  Head Start grantees are required to have Singl...
# 4  The Office of Refugee Resettlement (ORR) withi...

# %%
#Report Numbers are Unique Identifiers
reports_df['Report Number(s)'].value_counts()
# Out:
# A-05-17-00000      3
# A-07-16-00486      3
# A-04-20-02031      2
# A-02-17-01026      2
# A-07-21-00609      2
#                   ..
# OEI-03-16-00420    1
# OEI-03-17-00410    1
# OEI-03-16-00540    1
# OEI-03-17-00360    1
# OEI-05-22-00290    1
# Name: Report Number(s), Length: 717, dtype: int64

# %% [markdown]
# Let's remove duplicates of any Report Number or Summary

# %%
#Drop Duplicates for Summaries Data
mask = reports_df['Workplan_Title'].notna() & reports_df['Workplan_Summary'].notna()

reports_df = reports_df[mask].drop_duplicates()

reports_df.shape
# Out:
# (584, 3)

# %% [markdown]
# In total, the OIG Work Plan has:
# - 659 Summaries, and
# - 584 connected reports

# %% [markdown]
# #Digging Deeper into the text data

# %%
#Determine Stopwords
stopwords = nltk.corpus.stopwords.words('english')

#Add Stopwords (asp and amp were relics of links within the page)
stopwords.extend(['on',
                  'or', 
                  'to', 
                  'a', 
                  'as', 
                  'of', 
                  'for',
                  'this', 
                  'by', 
                  's',
                  'oig',
                  'hhs',
                  'amp',
                  'asp',
                  'href',
                  'determine',
                  'whether',
                  'will',
                  'review',
                  'asp',
                  'amp',
                  'oas',
                  'oei',
                  't t',
                  'n'])

# %%
################################
# Tokenize Work Plan Summaries #
################################

workplan_clean_df = workplan_df.copy()

#Set tokenizer as regex tokenizer to remove punctuation
tokenizer = RegexpTokenizer(r'\w+')

wp_init_srs = [paragraph.lower() for paragraph in workplan_df["Summary"]]

tokenized_sums = [[i for i in tokenizer.tokenize(sent) if i not in stopwords] 
                  for sent in wp_init_srs]

# Regex Stemmer (Other Stemmers didn't seem to work well)
Reg_stemmer = RegexpStemmer("ing$|s$|ies$")

tokenized_stemmed_sums = [[Reg_stemmer.stem(word) for word in sent] for sent in tokenized_sums]

# Set new column of tokenized summaries
workplan_clean_df["summary_tokenized"] = tokenized_stemmed_sums

workplan_clean_df["summary_token_num"] = [len(sent) for sent in tokenized_stemmed_sums]

#Set of unique tokens
workplan_clean_df["summary_unique_token"] = [len(set(sum_tok)) for sum_tok in workplan_clean_df["summary_tokenized"]]

# %%
#Is there any noticeable difference across the components for presented summary length?
workplan_clean_df[["Component", "summary_token_num","summary_unique_token"]].groupby('Component').agg(['sum', 'mean', 'min', 'max'])
# Out:
#                                                    summary_token_num  \
#                                                                  sum
# Component
# Office of Audit Services                                       37784
# Office of Audit Services and Office of Evaluati...                88
# Office of Evaluation and Inspections                           20166
#
#                                                                         \
#                                                          mean min  max
# Component
# Office of Audit Services                            89.323877  19  273
# Office of Audit Services and Office of Evaluati...  88.000000  88   88
# Office of Evaluation and Inspections                86.179487  31  230
#
#                                                    summary_unique_token  \
#                                                                     sum
# Component
# Office of Audit Services                                          25077
# Office of Audit Services and Office of Evaluati...                   53
# Office of Evaluation and Inspections                              13688
#
#
#                                                          mean min  max
# Component
# Office of Audit Services                            59.283688  16  147
# Office of Audit Services and Office of Evaluati...  53.000000  53   53
# Office of Evaluation and Inspections                58.495726  26  119

# %%
#Is there any noticeable difference across the components for Agency?
workplan_clean_df[["Agency", "summary_token_num","summary_unique_token"]].groupby('Agency').agg(['count', 'sum', 'mean', 'min', 'max'])
# Out:
#                                                    summary_token_num         \
#                                                                count    sum
# Agency
# ACF                                                                3    274
# ACF, CDC, CMS, HRSA, IHS, NIH, SAMHSA                              1     79
# ASA                                                                1    110
# ASFR                                                               1     59
# ASPR, CDC, FDA, NIH, CMS                                           1     36
# Administration for Children and Families                          46   4673
# Administration for Children and Families, CDC, ...                 1     56
# Administration for Children and Families;  Cent...                 1     69
# Administration for Community Living                                6    615
# All STAFFDIV/OPDIVs                                                1     19
# Assistant Secretary for Preparedness and Response                  6    540
# CDC, ACF                                                           1    107
# CDC, NIH, AHRQ                                                     1     69
# CMS, AHRQ                                                          1     87
# CMS, AHRQ, OMHA                                                    1    124
# CMS, ASPR                                                          1     98
# CMS, FDA                                                           1     79
# Centers for Disease Control and Prevention                        18   2097
# Centers for Medicare and Medicaid Services                       415  34609
# FDA, NIH, CMS                                                      1     69
# Food & Drug Administration                                         1     74
# Food and Drug Administration                                      20   1883
# HHS                                                                4    324
# HHS, OCR, CMS                                                      1    184
# Health Resources & Services Administration                         2    230
# Health Resources and Services Administration                      13   1537
# IHS  NIH  HRSA  CDC                                                1     49
# Indian Health Service                                             15   1834
# Indian Health Services                                             5    439
# National Institutes of Health                                     26   2432
# OS                                                                14   1167
# OS, ACF, ACL, AHRQ, CDC, FDA, HRSA, NIH, SAMHSA                    1     48
# OS, ACF, CMS, CDC, FDA                                             1     94
# OS, CDC, ASPR                                                      1     88
# OS, HRSA, CDC                                                      1     48
# OS, OIG, CMS, FDA, CDC                                             1     81
# Office of Evaluation and Inspections                               1    103
# Office of Inspector General                                        1     48
# Office of the Assistant Secretary for Administr...                 3    208
# Office of the Assistant Secretary for Financial...                 1     86
# Office of the Assistant Secretary for Preparedn...                 2    282
# Office of the Secretary                                            5    372
# Other                                                             14   1155
# Other Public Health Reviews                                        4    270
# Substance Abuse and Mental Health Services Admi...                13   1250
#
#                                                                           \
#                                                           mean  min  max
# Agency
# ACF                                                  91.333333   57  114
# ACF, CDC, CMS, HRSA, IHS, NIH, SAMHSA                79.000000   79   79
# ASA                                                 110.000000  110  110
# ASFR                                                 59.000000   59   59
# ASPR, CDC, FDA, NIH, CMS                             36.000000   36   36
# Administration for Children and Families            101.586957   52  228
# Administration for Children and Families, CDC, ...   56.000000   56   56
# Administration for Children and Families;  Cent...   69.000000   69   69
# Administration for Community Living                 102.500000   58  142
# All STAFFDIV/OPDIVs                                  19.000000   19   19
# Assistant Secretary for Preparedness and Response    90.000000   58  128
# CDC, ACF                                            107.000000  107  107
# CDC, NIH, AHRQ                                       69.000000   69   69
# CMS, AHRQ                                            87.000000   87   87
# CMS, AHRQ, OMHA                                     124.000000  124  124
# CMS, ASPR                                            98.000000   98   98
# CMS, FDA                                             79.000000   79   79
# Centers for Disease Control and Prevention          116.500000   65  197
# Centers for Medicare and Medicaid Services           83.395181   28  264
# FDA, NIH, CMS                                        69.000000   69   69
# Food & Drug Administration                           74.000000   74   74
# Food and Drug Administration                         94.150000   47  149
# HHS                                                  81.000000   73   84
# HHS, OCR, CMS                                       184.000000  184  184
# Health Resources & Services Administration          115.000000   93  137
# Health Resources and Services Administration        118.230769   58  230
# IHS  NIH  HRSA  CDC                                  49.000000   49   49
# Indian Health Service                               122.266667   45  273
# Indian Health Services                               87.800000   39  122
# National Institutes of Health                        93.538462   46  146
# OS                                                   83.357143   49  117
# OS, ACF, ACL, AHRQ, CDC, FDA, HRSA, NIH, SAMHSA      48.000000   48   48
# OS, ACF, CMS, CDC, FDA                               94.000000   94   94
# OS, CDC, ASPR                                        88.000000   88   88
# OS, HRSA, CDC                                        48.000000   48   48
# OS, OIG, CMS, FDA, CDC                               81.000000   81   81
# Office of Evaluation and Inspections                103.000000  103  103
# Office of Inspector General                          48.000000   48   48
# Office of the Assistant Secretary for Administr...   69.333333   34  103
# Office of the Assistant Secretary for Financial...   86.000000   86   86
# Office of the Assistant Secretary for Preparedn...  141.000000  112  170
# Office of the Secretary                              74.400000   30  105
# Other                                                82.500000   46  116
# Other Public Health Reviews                          67.500000   33   83
# Substance Abuse and Mental Health Services Admi...   96.153846   70  129
#
#                                                    summary_unique_token  \
#                                                                   count
# Agency
# ACF                                                                   3
# ACF, CDC, CMS, HRSA, IHS, NIH, SAMHSA                                 1
# ASA                                                                   1
# ASFR                                                                  1
# ASPR, CDC, FDA, NIH, CMS                                              1
# Administration for Children and Families                             46
# Administration for Children and Families, CDC, ...                    1
# Administration for Children and Families;  Cent...                    1
# Administration for Community Living                                   6
# All STAFFDIV/OPDIVs                                                   1
# Assistant Secretary for Preparedness and Response                     6
# CDC, ACF                                                              1
# CDC, NIH, AHRQ                                                        1
# CMS, AHRQ                                                             1
# CMS, AHRQ, OMHA                                                       1
# CMS, ASPR                                                             1
# CMS, FDA                                                              1
# Centers for Disease Control and Prevention                           18
# Centers for Medicare and Medicaid Services                          415
# FDA, NIH, CMS                                                         1
# Food & Drug Administration                                            1
# Food and Drug Administration                                         20
# HHS                                                                   4
# HHS, OCR, CMS                                                         1
# Health Resources & Services Administration                            2
# Health Resources and Services Administration                         13
# IHS  NIH  HRSA  CDC                                                   1
# Indian Health Service                                                15
# Indian Health Services                                                5
# National Institutes of Health                                        26
# OS                                                                   14
# OS, ACF, ACL, AHRQ, CDC, FDA, HRSA, NIH, SAMHSA                       1
# OS, ACF, CMS, CDC, FDA                                                1
# OS, CDC, ASPR                                                         1
# OS, HRSA, CDC                                                         1
# OS, OIG, CMS, FDA, CDC                                                1
# Office of Evaluation and Inspections                                  1
# Office of Inspector General                                           1
# Office of the Assistant Secretary for Administr...                    3
# Office of the Assistant Secretary for Financial...                    1
# Office of the Assistant Secretary for Preparedn...                    2
# Office of the Secretary                                               5
# Other                                                                14
# Other Public Health Reviews                                           4
# Substance Abuse and Mental Health Services Admi...                   13
#
#                                                                             \
#                                                       sum        mean  min
# Agency
# ACF                                                   181   60.333333   41
# ACF, CDC, CMS, HRSA, IHS, NIH, SAMHSA                  51   51.000000   51
# ASA                                                    76   76.000000   76
# ASFR                                                   37   37.000000   37
# ASPR, CDC, FDA, NIH, CMS                               29   29.000000   29
# Administration for Children and Families             3114   67.695652   38
# Administration for Children and Families, CDC, ...     39   39.000000   39
# Administration for Children and Families;  Cent...     46   46.000000   46
# Administration for Community Living                   441   73.500000   47
# All STAFFDIV/OPDIVs                                    16   16.000000   16
# Assistant Secretary for Preparedness and Response     376   62.666667   46
# CDC, ACF                                               78   78.000000   78
# CDC, NIH, AHRQ                                         51   51.000000   51
# CMS, AHRQ                                              60   60.000000   60
# CMS, AHRQ, OMHA                                        83   83.000000   83
# CMS, ASPR                                              71   71.000000   71
# CMS, FDA                                               50   50.000000   50
# Centers for Disease Control and Prevention           1456   80.888889   50
# Centers for Medicare and Medicaid Services          22922   55.233735   21
# FDA, NIH, CMS                                          46   46.000000   46
# Food & Drug Administration                             53   53.000000   53
# Food and Drug Administration                         1241   62.050000   29
# HHS                                                   258   64.500000   53
# HHS, OCR, CMS                                         133  133.000000  133
# Health Resources & Services Administration            146   73.000000   57
# Health Resources and Services Administration          949   73.000000   36
# IHS  NIH  HRSA  CDC                                    31   31.000000   31
# Indian Health Service                                1192   79.466667   34
# Indian Health Services                                300   60.000000   28
# National Institutes of Health                        1710   65.769231   36
# OS                                                    766   54.714286   37
# OS, ACF, ACL, AHRQ, CDC, FDA, HRSA, NIH, SAMHSA        40   40.000000   40
# OS, ACF, CMS, CDC, FDA                                 69   69.000000   69
# OS, CDC, ASPR                                          63   63.000000   63
# OS, HRSA, CDC                                          37   37.000000   37
# OS, OIG, CMS, FDA, CDC                                 67   67.000000   67
# Office of Evaluation and Inspections                   68   68.000000   68
# Office of Inspector General                            39   39.000000   39
# Office of the Assistant Secretary for Administr...    158   52.666667   25
# Office of the Assistant Secretary for Financial...     59   59.000000   59
# Office of the Assistant Secretary for Preparedn...    188   94.000000   88
# Office of the Secretary                               251   50.200000   24
# Other                                                 781   55.785714   35
# Other Public Health Reviews                           200   50.000000   26
# Substance Abuse and Mental Health Services Admi...    865   66.538462   49
#
#
#                                                     max
# Agency
# ACF                                                  77
# ACF, CDC, CMS, HRSA, IHS, NIH, SAMHSA                51
# ASA                                                  76
# ASFR                                                 37
# ASPR, CDC, FDA, NIH, CMS                             29
# Administration for Children and Families            136
# Administration for Children and Families, CDC, ...   39
# Administration for Children and Families;  Cent...   46
# Administration for Community Living                 102
# All STAFFDIV/OPDIVs                                  16
# Assistant Secretary for Preparedness and Response    78
# CDC, ACF                                             78
# CDC, NIH, AHRQ                                       51
# CMS, AHRQ                                            60
# CMS, AHRQ, OMHA                                      83
# CMS, ASPR                                            71
# CMS, FDA                                             50
# Centers for Disease Control and Prevention          135
# Centers for Medicare and Medicaid Services          126
# FDA, NIH, CMS                                        46
# Food & Drug Administration                           53
# Food and Drug Administration                        104
# HHS                                                  71
# HHS, OCR, CMS                                       133
# Health Resources & Services Administration           89
# Health Resources and Services Administration        104
# IHS  NIH  HRSA  CDC                                  31
# Indian Health Service                               147
# Indian Health Services                               79
# National Institutes of Health                        98
# OS                                                   69
# OS, ACF, ACL, AHRQ, CDC, FDA, HRSA, NIH, SAMHSA      40
# OS, ACF, CMS, CDC, FDA                               69
# OS, CDC, ASPR                                        63
# OS, HRSA, CDC                                        37
# OS, OIG, CMS, FDA, CDC                               67
# Office of Evaluation and Inspections                 68
# Office of Inspector General                          39
# Office of the Assistant Secretary for Administr...   77
# Office of the Assistant Secretary for Financial...   59
# Office of the Assistant Secretary for Preparedn...  100
# Office of the Secretary                              72
# Other                                                83
# Other Public Health Reviews                          60
# Substance Abuse and Mental Health Services Admi...   86

# %% [markdown]
# ## Visualizations

# %%
mask = [True if comp in ["Office of Audit Services", "Office of Evaluation and Inspections"] 
        else False for comp in workplan_clean_df["Component"]]

plt.figure(figsize = (15,8))

sns.catplot(x="Component", 
            y="summary_token_num", 
            kind="box", 
            data=workplan_clean_df[mask],
            height = 4,
            aspect = 12/9).set(title ="Components and Summary Length")

# %%
#How many unique tokens do we have from our list of work plan summaries?
len(set(workplan_clean_df["summary_tokenized"].apply(pd.Series).stack().unique()))
# Out:
# 4331

# %%
#Visualize the number of tokens for summaries and reports
fig, ax = plt.subplots(figsize= (10,6), sharex = True, sharey = True)

sns.histplot(data=workplan_clean_df, 
             x="summary_token_num", 
             bins = 25,
             color = 'lightblue',
             alpha = .6,
             label = 'Total Tokens',
             linewidth = 2)

sns.histplot(data=workplan_clean_df, 
             x="summary_unique_token", 
             bins = 25,
             color = 'darkblue',
             alpha = .40,
             label = 'Unique Tokens',
             linewidth = 0)

#Style Plot
sns.despine()
ax.set_title("Work Plan Summaries: Cleaned Token Number Distributions")
ax.set_xlabel("Number of Tokens")
ax.set_ylabel("Summary Count")
ax.legend()

# %% [markdown]
# ### Work Plan: Word Cloud of Frequent Words
# - What words are we seeing occur the most frequently?

# %%
#########################
# Workplan: Word Cloud  #
#########################

#Visualize the number of tokens for summaries and reports
fig, ax = plt.subplots(figsize= (14,10))

# Start with one review:
text = str([' '.join(word) for word in workplan_clean_df["summary_tokenized"]])

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=60, 
                      max_words=30,
                      background_color = 'black',
                      colormap = 'Blues').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("OIG Work Plans", size = 32)
plt.show()

# %% [markdown]
# ## OIG Reports
# - Reports are summaries of the specific findings and recommendations that OIG discovers after the work on a specific project has been completed. They include details on the project scope, as well as recommendations found from the project itself.

# %%
reports_df.head()
# Out:
#   Report Number(s)                                     Workplan_Title  \
# 0    A-02-17-02005  New York Did Not Have Adequate Oversight of It...
# 1    A-02-16-02009  The Administration for Children and Families R...
# 2    A-09-16-01004  The Administration for Children and Families R...
# 3    A-06-17-07003  The Administration for Children and Families D...
# 4    A-02-16-02013  The Children's Village, Inc., an Administratio...
#
#                                     Workplan_Summary
# 0  The Temporary Assistance for Needy Families (T...
# 1  The Administration for Children and Families (...
# 2  Head Start grantees are required to have Singl...
# 3  Head Start grantees are required to have Singl...
# 4  The Office of Refugee Resettlement (ORR) withi...

# %%
reports_df['Workplan_Summary'] = reports_df['Workplan_Summary'].fillna(' ')

# %%
reports_df['Workplan_Summary']
# Out:
# 0      The Temporary Assistance for Needy Families (T...
# 1      The Administration for Children and Families (...
# 2      Head Start grantees are required to have Singl...
# 3      Head Start grantees are required to have Singl...
# 4      The Office of Refugee Resettlement (ORR) withi...
#                              ...
# 713    When Congress established average sales price ...
# 715    Background checks for employees of long-term-c...
# 720    For the fiscal year (FY) 2021 coordinated over...
# 724    This report provides the results of our review...
# 725    This report provides the results of our review...
# Name: Workplan_Summary, Length: 584, dtype: object

# %%
#Subset out any workplan product with no title
reports_clean_df = reports_df[reports_df['Workplan_Title'].notna()]

# %%
################################
# Tokenize Work Plan Reports   #
################################
#Set tokenizer as regex tokenizer to remove punctuation
tokenizer = RegexpTokenizer(r'\w+')

wp_init_srs = [paragraph.lower() for paragraph in reports_clean_df["Workplan_Summary"]]

tokenized_sums = [[i for i in tokenizer.tokenize(sent) if i not in stopwords] 
                  for sent in wp_init_srs]

# Regex Stemmer (Other Stemmers didn't seem to work well)
Reg_stemmer = RegexpStemmer("ing$|s$|ies$")

tokenized_stemmed_sums = [[Reg_stemmer.stem(word) for word in sent] for sent in tokenized_sums]

# Set new column of tokenized summaries
reports_clean_df["summary_tokenized"] = tokenized_stemmed_sums

#Number of tokens after cleaning data
reports_clean_df["summary_token_num"] = [len(sent) for sent in tokenized_stemmed_sums]

#Set of unique tokens
reports_clean_df["summary_unique_token"] = [len(set(sum_tok)) for sum_tok in reports_clean_df["summary_tokenized"]]

# %%
#Show Cleaned Dataframe
reports_clean_df.head()
# Out:
#   Report Number(s)                                     Workplan_Title  \
# 0    A-02-17-02005  New York Did Not Have Adequate Oversight of It...
# 1    A-02-16-02009  The Administration for Children and Families R...
# 2    A-09-16-01004  The Administration for Children and Families R...
# 3    A-06-17-07003  The Administration for Children and Families D...
# 4    A-02-16-02013  The Children's Village, Inc., an Administratio...
#
#                                     Workplan_Summary  \
# 0  The Temporary Assistance for Needy Families (T...
# 1  The Administration for Children and Families (...
# 2  Head Start grantees are required to have Singl...
# 3  Head Start grantees are required to have Singl...
# 4  The Office of Refugee Resettlement (ORR) withi...
#
#                                    summary_tokenized  summary_token_num  \
# 0  [temporary, assistance, needy, famil, tanf, pr...                357
# 1  [administration, children, famil, acf, proces,...                202
# 2  [head, start, grantee, required, single, audit...                137
# 3  [head, start, grantee, required, single, audit...                249
# 4  [office, refugee, resettlement, orr, within, d...                342
#
#    summary_unique_token
# 0                   159
# 1                   108
# 2                    87
# 3                   127
# 4                   186

# %%
#How many unique tokens do we have from the reports data?
#https://stackoverflow.com/questions/38895856/how-to-compile-all-lists-in-a-column-into-one-unique-list
print("Total Tokens:")
len(set(reports_clean_df["summary_tokenized"].apply(pd.Series).stack().unique()))
# Out:
# Total Tokens:
# 5775

# %%
def word_stats(df):
    try:
        total_tokens = df["summary_token_num"].sum()
        
    except Exception as e:
        print(e)

    try:
        unique_tokens = (len(set(df["summary_tokenized"].apply(pd.Series).stack().unique())))

    except Exception as e:
        print(e)

    return [total_tokens, unique_tokens]

# %% [markdown]
# ### OIG Reports: Word Cloud of Frequent Words
# - What words are we seeing occur the most frequently?

# %%
#########################
# Reports: Word Cloud   #
#########################
#Visualize the number of tokens for summaries and reports
fig, ax = plt.subplots(figsize= (14,10))

# Start with one review:
text = str([' '.join(word) for word in reports_clean_df["summary_tokenized"]])

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=60,
                      max_words=30,
                      background_color = 'black',
                      colormap = 'Blues_r').generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title("OIG Reports", size = 32)
plt.show()

# %%
#Visualize the number of tokens for summaries and reports
fig, ax = plt.subplots(figsize= (10,6), 
                       sharex = True, 
                       sharey = True)

sns.histplot(data=reports_clean_df, 
             x="summary_token_num", 
             bins = 10,
             color = 'blue',
             alpha = .6,
             label = 'Total Tokens',
             linewidth = 2)

sns.histplot(data=reports_clean_df, 
             x="summary_unique_token", 
             bins = 10,
             color = 'orange',
             alpha = .75,
             label = 'Unique Tokens',
             linewidth = 0)

#Style Plot
sns.despine()
ax.set_title("Work Plan Reports: Cleaned Token Number Distributions")
ax.set_xlabel("Number of Tokens")
ax.set_ylabel("Summaries")
ax.set_xlim(0,1000)
ax.legend()

# %%
#Mean token num
print(round(reports_clean_df["summary_token_num"].mean(), 0))
print(round(reports_clean_df["summary_unique_token"].mean(),0))
# Out:
# 257.0
# 129.0

# %%
workplan_clean_df
# Out:
#     Announced or Revised                                      Agency  \
# 0              Completed    Administration for Children and Families
# 1              Completed    Administration for Children and Families
# 2              Completed    Administration for Children and Families
# 3                 Nov-16    Administration for Children and Families
# 4           October 2020    Administration for Children and Families
# ..                   ...                                         ...
# 654            June 2022  Centers for Medicare and Medicaid Services
# 655            June 2022  Centers for Medicare and Medicaid Services
# 656            June 2022    Administration for Children and Families
# 657            June 2022                       Indian Health Service
# 658            June 2022  Centers for Medicare and Medicaid Services
#
#                                                  Title  \
# 0    States' Accuracy of Reporting TANF Spending In...
# 1    Head Start: Review of Single Audit Findings an...
# 2       Unaccompanied Children Program Grantee Reviews
# 3    Recommendation Follow-Up: Office of Refugee Re...
# 4    ACF Oversight of Guardian Ad Litem Requirement...
# ..                                                 ...
# 654  Medicare Administrative Contractor Cost Report...
# 655  States' and MCOs' Compliance With Mental Healt...
# 656  Audit of the Low Income Home Energy Assistance...
# 657  Indian Health Service Capacity To Manage Suppl...
# 658  Strategies To Improve Access to Maternal Healt...
#
#                                 Component  \
# 0                Office of Audit Services
# 1                Office of Audit Services
# 2                Office of Audit Services
# 3    Office of Evaluation and Inspections
# 4    Office of Evaluation and Inspections
# ..                                    ...
# 654              Office of Audit Services
# 655              Office of Audit Services
# 656              Office of Audit Services
# 657  Office of Evaluation and Inspections
# 658  Office of Evaluation and Inspections
#
#                                       Report Number(s)  \
# 0                        A-02-17-02005;  W-00-17-25100
# 1    A-02-16-02009,  A-09-16-01004,  A-06-17-07003;...
# 2    A-02-16-02013;  A-04-16-03566;  A-02-16-02007;...
# 3                                      OEI-09-16-00260
# 4                                      OEI-12-16-00120
# ..                                                 ...
# 654                                      W-00-22-35886
# 655                                      W-00-22-31565
# 656                                      W-00-22-20036
# 657                                    OEI-06-22-00320
# 658                                    OEI-05-22-00330
#
#     Expected Issue Date (FY)  \
# 0                       2021
# 1                       2018
# 2                       2020
# 3                       2017
# 4                       2022
# ..                       ...
# 654                     2023
# 655                     2023
# 656                     2023
# 657                     2023
# 658                     2023
#
#                                           Website_Link  \
# 0    https://oig.hhs.gov/reports-and-publications/w...
# 1    https://oig.hhs.gov/reports-and-publications/w...
# 2    https://oig.hhs.gov/reports-and-publications/w...
# 3    https://oig.hhs.gov/reports-and-publications/w...
# 4    https://oig.hhs.gov/reports-and-publications/w...
# ..                                                 ...
# 654  https://oig.hhs.gov/reports-and-publications/w...
# 655  https://oig.hhs.gov/reports-and-publications/w...
# 656  https://oig.hhs.gov/reports-and-publications/w...
# 657  https://oig.hhs.gov/reports-and-publications/w...
# 658  https://oig.hhs.gov/reports-and-publications/w...
#
#                                                Summary  \
# 0    The Temporary Assistance for Needy Families (T...
# 1    Effective for awards made on or after December...
# 2    Under the Homeland Security Act of 2002, § 462...
# 3    Under the Homeland Security Act of 2002, § 462...
# 4    As a condition of receiving Child Abuse Preven...
# ..                                                 ...
# 654  HHS contracts with Medicare Administrative Con...
# 655  The Paul Wellstone and Pete Domenici Mental He...
# 656  The Low Income Home Energy Assistance Program ...
# 657  The Indian Health Service (IHS) Sanitation Fac...
# 658  Pregnant people in the United States experienc...
#
#                                      summary_tokenized  summary_token_num  \
# 0    [temporary, assistance, needy, famil, tanf, pr...                101
# 1    [effective, award, made, december, 26, 2014, n...                 63
# 2    [homeland, security, act, 2002, 462, office, r...                 73
# 3    [homeland, security, act, 2002, 462, office, r...                 81
# 4    [condition, receiv, child, abuse, prevention, ...                 68
# ..                                                 ...                ...
# 654  [contract, medicare, administrative, contracto...                115
# 655  [paul, wellstone, pete, domenici, mental, heal...                112
# 656  [low, income, home, energy, assistance, progra...                130
# 657  [indian, health, service, ih, sanitation, faci...                 78
# 658  [pregnant, people, united, state, experience, ...                 69
#
#      summary_unique_token
# 0                      61
# 1                      43
# 2                      52
# 3                      57
# 4                      55
# ..                    ...
# 654                    75
# 655                    73
# 656                    81
# 657                    61
# 658                    40
#
# [659 rows x 11 columns]

# %%
#Visualize the number of tokens for summaries and reports
fig, ax = plt.subplots(figsize= (10,6), sharex = True)

#Comparing the number of tokens 
sns.histplot(data=workplan_clean_df, 
             x="summary_token_num", 
             bins = 10,
             color = 'lightblue',
             alpha = .8,
             label = 'Total Tokens',
             linewidth = 2,
             ax = ax)

sns.histplot(data=workplan_clean_df, 
             x="summary_unique_token", 
             bins = 10,
             ax = ax,
             color = 'green',
             alpha = .6,
             linewidth = 0,
             label = 'Unique Tokens')

#Style Plot
sns.despine()
ax.set_title("Work Plan Summaries: Cleaned Token Number Distributions")
ax.set_xlabel("Number of Total Tokens")
ax.set_ylabel("Summaries")
ax.set_xlim(0,1000)
ax.legend()

# %%
#Mean token num
print(round(workplan_clean_df["summary_token_num"].mean(), 0))
print(round(workplan_clean_df["summary_unique_token"].mean(),0))
# Out:
# 88.0
# 59.0

# %% [markdown]
# Let's move on to the next step...
# https://colab.research.google.com/drive/1wD4E8EhCG8bRX5k8MOC90Yc54QD12HH-?usp=sharing
